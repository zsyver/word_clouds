# %% [markdown]
# <a href="https://colab.research.google.com/github/zsyver/word_clouds/blob/main/word_cloud_experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wordcloud
# !pip install fileupload
# !pip install ipywidgets
# !jupyter nbextension install --py --user fileupload
# !jupyter nbextension enable --py fileupload

import wordcloud
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display
import fileupload
import io
import sys
# Out:
# ...
# Installing /usr/local/lib/python3.7/dist-packages/fileupload/static -> fileupload
# Up to date: /root/.local/share/jupyter/nbextensions/fileupload/widget.js
# Up to date: /root/.local/share/jupyter/nbextensions/fileupload/extension.js
# Up to date: /root/.local/share/jupyter/nbextensions/fileupload/fileupload/widget.js
# - Validating: OK
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable fileupload --user --py
#
# Enabling notebook extension fileupload/extension...
# Paths used for configuration of notebook:
#     	/root/.jupyter/nbconfig/notebook.json
#       - Validating: OK
# Paths used for configuration of notebook:
#     	/root/.jupyter/nbconfig/notebook.json

# %%
ls
# Out:
#  articles_confed.txt                    fed_no_ten.txt
# 'Copy of word_cloud_experiment.ipynb'   louis_purchase.txt
#  day_of_infamy.txt                      the_constitution.txt
#  doi.txt                                won_inquiry.txt
#  emanc_proc.txt                         word_cloud_tarzan.ipynb
#  fed_no_fiftyone.txt

# %%
def calculate_frequencies(file_contents):
    # Here is a list of punctuations and uninteresting words you can use to process your text
    punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    uninteresting_words = ["the", "a", "to", "if", "is", "it", "of", "and", "or", "an", "as", "i", "me", "my", \
    "we", "our", "ours", "you", "your", "yours", "he", "she", "him", "his", "her", "hers", "its", "they", "them", \
    "their", "what", "which", "who", "whom", "this", "that", "am", "are", "was", "were", "be", "been", "being", \
    "have", "has", "had", "do", "does", "did", "but", "at", "by", "with", "from", "here", "when", "where", "how", \
    "all", "any", "both", "each", "few", "more", "some", "these", "such","not", "for", "in", "on", "one", "may", "those", "no", "nor", "too", "very", "can", "will", "just"]
    freq_dict = {}
    file_contents = file_contents.split()
    join_string = ""
    # LEARNER CODE START HERE
    for word in file_contents:
        join_string = ''.join(i for i in word if i.isalpha())
        if join_string.lower() not in uninteresting_words:
            if join_string.lower() not in freq_dict:
                freq_dict[join_string.lower()] = 1
            else:
                freq_dict[join_string.lower()] += 1
    
    
    #wordcloud
    cloud = wordcloud.WordCloud()
    cloud.generate_from_frequencies(freq_dict)
    return cloud.to_array()

# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks'

# %%
ls
# Out:
#  articles_confed.txt                    fed_no_ten.txt
# 'Copy of word_cloud_experiment.ipynb'   louis_purchase.txt
#  day_of_infamy.txt                      the_constitution.txt
#  doi.txt                                won_inquiry.txt
#  emanc_proc.txt                         word_cloud_tarzan.ipynb
#  fed_no_fiftyone.txt

# %% [markdown]
# I would like to see the word cloud representation of a variety of historically significant manuscripts for the purpose of illuminating their meaning in a data-driven way. The manuscripts that I have chosen for this endeavor are the following:
#
# The Articles of Confederation and Perpetual Union
#
# The Declaration of Independence
#
# The Constitution
#
# Emancipation Proclamation
#
# "Day Of Infamy"
#
# Louisiana Purchase Treaty (1803)
#
# Federalist No. 10
#
# Federalist Papers No. 51
#
# Wealth of Nations

# %%
import os 
print(os.listdir())
# Out:
# ['doi.txt', 'emanc_proc.txt', 'louis_purchase.txt', 'day_of_infamy.txt', 'the_constitution.txt', 'articles_confed.txt', 'fed_no_ten.txt', 'fed_no_fiftyone.txt', 'won_inquiry.txt', 'word_cloud_tarzan.ipynb', 'Copy of word_cloud_experiment.ipynb']

# %%
file_strings = []

for i in os.listdir():
  if i.endswith(".txt"):
    with open (i, 'r') as file:
      file_string = file.read().replace('\n','')
      file_strings.append(file_string)

# This is the code that I referenced for my own for loop and query across the memory
# with open ('tarzan.txt', 'r') as file:
#   tarzan_string = file.read().replace('\n','')

# %%
# with open ('doi.txt', 'r') as file:
#   doi = file.read().replace('\n', '')

# %%
for i in range(len(file_strings)):
  myimage = calculate_frequencies(file_strings[i])
  plt.imshow(myimage, interpolation = 'nearest')
  plt.axis('off')
  plt.show()

# Again, source code is below for my above code
# myimage = calculate_frequencies(file_strings[3])
# plt.imshow(myimage, interpolation = 'nearest')
# plt.axis('off')
# plt.show()

# %% [markdown]
# Source: https://gutenberg.org/
# Source: https://www.loc.gov/

# %% [markdown]
# Further development idea: Create a variety of word clouds for famous speeches and other contexts that are considered "common sense" or taught at the elementary level.
#
# People can review statistics (simple statistics) and simple figures for a general idea of what is going on at a national and historical level.
